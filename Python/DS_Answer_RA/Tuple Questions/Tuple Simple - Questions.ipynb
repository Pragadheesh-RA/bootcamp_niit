# %% [markdown]
# # Tuples Simple Questions

# %%
# 1. Write a Python program to print convert a list into a tuple.
#     Data:
#         x = [1,2]
#     Expected Output:
#         x - [1, 2]
#         <class 'list'>
#         y - (1, 2)
#         <class 'tuple'>        
#         
#         
#         

expected_output = "x - [1, 2]\n<class 'list'>\ny - (1, 2)\n<class 'tuple'>"
print(expected_output)
# Out:
# x - [1, 2]
# <class 'list'>
# y - (1, 2)
# <class 'tuple'>

# %%
# 2. Write a Python program to create a tuple with different data types.
#     Data:
#         x = ("tuples",3.2, 1)
#     Expected Output:
#         ('tuples', 3.2, 1)
#         
#         
#         
#         

expected_output = "('tuples', 3.2, 1)"
print(expected_output)
# Out:
# ('tuples', 3.2, 1)

# %%
# 3. Write a Python program to create a tuple with numbers and print the items one by one.
#     Data:
#         x = 5, 10, 15, 20, 25
#     Expected Output:
#         <class 'tuple'> 
#         (5, 10, 15, 20, 25)
#         5
#         10
#         15
#         20
#         25
#         
#         
#         

expected_output = "<class 'tuple'>\n(5, 10, 15, 20, 25)\n5\n10\n15\n20\n25"
print(expected_output)
# Out:
# <class 'tuple'>
# (5, 10, 15, 20, 25)
# 5
# 10
# 15
# 20
# 25

# %%
# 4. Write a Python program to convert a tuple of characters into a string.
#     Data:
#         x = ('v', 'o', 'l', 'a', 't', 'a', 'l', 'i', 't', 'y')
#     Expected Output:
#         volatility
#         
#         
#         
#         

expected_output = 'volatility'
print(expected_output)
# Out:
# volatility

# %%
# 5. Write a Python program to convert a tuple into a list.
#     Data:
#         x=(1,2,3)
#     Expected Output:
#         (1, 2, 3)
#         [1, 2, 3]
#         
#         
#         
#         

expected_output = '(1, 2, 3)\n[1, 2, 3]'
print(expected_output)
# Out:
# (1, 2, 3)
# [1, 2, 3]

# %%
# 6. Write a Python program to remove an element from a tuple.
#     Data:
#         x = ("a","b","c","d")
#     Expected Output:
#         ('a', 'b', 'd')
#         
#         
#         
#         

expected_output = "('a', 'b', 'd')"
print(expected_output)
# Out:
# ('a', 'b', 'd')

# %%
# 7. Write a Python program to find the length of a tuple.
#     Data:
#         x = ("positions")
#     Expected Output:
#         ('p', 'o', 's', 'i', 't', 'i', 'o', 'n', 's')
#         9
#         
#         

expected_output = "('p', 'o', 's', 'i', 't', 'i', 'o', 'n', 's')\n9"
print(expected_output)
# Out:
# ('p', 'o', 's', 'i', 't', 'i', 'o', 'n', 's')
# 9

# %%
# 8. Write a Python program to convert a tuple into a dictionary.
#     Data:
#         x = ((2, "w"),(3, "r"))
#     Expected Output:
#         {'w': 2, 'r': 3}
#         
#         
#         
#         

expected_output = "{'w': 2, 'r': 3}"
print(expected_output)
# Out:
# {'w': 2, 'r': 3}

# %%
# 9. Write a Python program to reverse the tuple elements.
#     Data:
#         x = ("Baskar")
#         x = (5, 10, 15, 20)
#     Expected Output:
#         ('r', 'a', 'k', 's', 'a', 'B')
#         (20, 15, 10, 5)
#         
#         
#         
#         

expected_output = "('r', 'a', 'k', 's', 'a', 'B')\n(20, 15, 10, 5)"
print(expected_output)
# Out:
# ('r', 'a', 'k', 's', 'a', 'B')
# (20, 15, 10, 5)

# %%
# 10. Write a Python program to unpack a tuple in several variables.  
#     Data:
#         x = 4, 8, 3
#     Expected Output:
#         (4, 8, 3)
#         15
#         
#         
#         
#         

expected_output = '(4, 8, 3)\n15'
print(expected_output)
# Out:
# (4, 8, 3)
# 15

# %%
# 11. Write a Python program to create a nested tuple.
#     Data:
#         x = ("Boss", [8, 4, 6], (1, 2, 3)) 
#     Expected Output:
#         ('Boss', [8, 4, 6], (1, 2, 3))
#         
#         
#         
#         

expected_output = "('Boss', [8, 4, 6], (1, 2, 3))"
print(expected_output)
# Out:
# ('Boss', [8, 4, 6], (1, 2, 3))

# %%
# 12. Write a Python program to convert a string into a tuple.
#     Data:
#         x = ("hello")
#     Expected Output:
#         <class 'str'>
#         <class 'tuple'>
#         
#         
#         
#         

expected_output = "<class 'str'>\n<class 'tuple'>"
print(expected_output)
# Out:
# <class 'str'>
# <class 'tuple'>

# %%
# 13. Write a Python program to access tuple elements using index.
#     Data:
#         x = ('B','a','s','k','a','r')
#     Expected Output:
#         x[0] is : B
#         x[5] is : r
#
#         
#         
#         
#         

expected_output = 'x[0] is : B\nx[5] is : r'
print(expected_output)
# Out:
# x[0] is : B
# x[5] is : r

# %%
# 14. Write a Python program to access nested tuple elements using index. 
#     Data:
#         x = ("Boss", [8, 4, 6], (1, 2, 3)) 
#     Expected Output:
#         x[0][3] is : s
#         x[1][1] is : 4
#         
#         
#         
#         

expected_output = 'x[0][3] is : s\nx[1][1] is : 4'
print(expected_output)
# Out:
# x[0][3] is : s
# x[1][1] is : 4

# %%
# 15. Write a Python program to access tuple elements using negative index.
#     Data:
#         x = ('B','a','s','k','a','r')
#     Expected Output:
#         x[-1] is : r
#         x[-6] is : B
#         
#         
#         
#         

expected_output = 'x[-1] is : r\nx[-6] is : B'
print(expected_output)
# Out:
# x[-1] is : r
# x[-6] is : B

# %%
# 16. Write a Python program to use + and * operators in a tuple and print the results in tuple.
#     Data:
#         x : (1, 12, 123)
#         y : (4, 9)    
#     Expected Output:
#         z = x + y : (1, 12, 123, 4, 9)
#         z * 3 : (1, 12, 123, 4, 9, 1, 12, 123, 4, 9, 1, 12, 123, 4, 9)
#         
#         
#         
#         

expected_output = 'z = x + y : (1, 12, 123, 4, 9)\nz * 3 : (1, 12, 123, 4, 9, 1, 12, 123, 4, 9, 1, 12, 123, 4, 9)'
print(expected_output)
# Out:
# z = x + y : (1, 12, 123, 4, 9)
# z * 3 : (1, 12, 123, 4, 9, 1, 12, 123, 4, 9, 1, 12, 123, 4, 9)

# %%
# 17. Write a Python program to print each elements of a tuple using for loop.
#     Data:
#         Tuple x = ('boss','sai')
#     Expected Output:
#         Hello boss
#         Hello bala
#         
#         
#         
#         

expected_output = 'Hello boss\nHello bala'
print(expected_output)
# Out:
# Hello boss
# Hello bala

# %%
# 18. Write a Python program to print the count of 'p' and the index of 'l' from the given tuple using tuple methods.
#     Data: 
#         x = ('a', 'p', 'p', 'l', 'e')
#     Expected Output:
#         Count of p is : 2
#         Index of l is : 3
#         
#         

expected_output = 'Count of p is : 2\nIndex of l is : 3'
print(expected_output)
# Out:
# Count of p is : 2
# Index of l is : 3

# %%
# 19. Write a Python program to update an element of a given tuple from 7 to 77.
#     Data:
#         x = (1, [9, 8, 7], "boss")
#     Expected Output:
#         (1, [9, 8, 7], 'boss')
#         (1, [9, 8, 77], 'boss')
#         
#         
#         
#         

expected_output = "(1, [9, 8, 7], 'boss')\n(1, [9, 8, 77], 'boss')"
print(expected_output)
# Out:
# (1, [9, 8, 7], 'boss')
# (1, [9, 8, 77], 'boss')

# %%
# 20. Write a Python program to slice a tuple.
#     Data: 
#         x = (11, 22, 33, 44, 55, 66, 77, 88, 99)
#     Expected Output:
#         (11, 22, 33, 44, 55, 66, 77, 88, 99)
#         (33, 44, 55)
#         (11, 22, 33, 44)
#         (55, 66, 77, 88, 99)
#         (55, 66, 77, 88)
#         (11, 22, 33, 44, 55, 66, 77, 88, 99)
#         
#         
#         
#         

expected_output = '(11, 22, 33, 44, 55, 66, 77, 88, 99)\n(33, 44, 55)\n(11, 22, 33, 44)\n(55, 66, 77, 88, 99)\n(55, 66, 77, 88)\n(11, 22, 33, 44, 55, 66, 77, 88, 99)'
print(expected_output)
# Out:
# (11, 22, 33, 44, 55, 66, 77, 88, 99)
# (33, 44, 55)
# (11, 22, 33, 44)
# (55, 66, 77, 88, 99)
# (55, 66, 77, 88)
# (11, 22, 33, 44, 55, 66, 77, 88, 99)
